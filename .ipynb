# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                Job Title               Salary Estimate  \
# 0           Data Modeler  $197K-$209K (Glassdoor est.)
# 1  Senior Data Scientist  $197K-$214K (Glassdoor est.)
# 2     Lead Data Engineer    $190K-$220K(Employer est.)
# 3     Lead Data Engineer    $190K-$220K(Employer est.)
# 4     Lead Data Engineer    $190K-$220K(Employer est.)
#
#                                      Job Description  Rating  \
# 0  The database modeler shall perform analysis of...     4.7
# 1  CK-12’s mission is to provide free access to o...     4.1
# 2  Credit Sesame is bringing cash and credit toge...     4.2
# 3  Credit Sesame is bringing cash and credit toge...     4.2
# 4  Credit Sesame is bringing cash and credit toge...     4.2
#
#             Company Name           Location       Headquarters  \
# 0       IT Concepts\n4.7       Landover, MD         Vienna, VA
# 1  CK-12 Foundation\n4.1      Palo Alto, CA      Palo Alto, CA
# 2     Credit Sesame\n4.2  Mountain View, CA  Mountain View, CA
# 3     Credit Sesame\n4.2  Mountain View, CA  Mountain View, CA
# 4     Credit Sesame\n4.2  Mountain View, CA  Mountain View, CA
#
#                   Size  Founded  Type of ownership  ... avg_salary  \
# 0  51 to 200 employees     2003  Company - Private  ...      197.0
# 1    1 to 50 employees     2007  Company - Private  ...      197.0
# 2  51 to 200 employees     2010  Company - Private  ...      190.0
# 3  51 to 200 employees     2010  Company - Private  ...      190.0
# 4  51 to 200 employees     2010  Company - Private  ...      190.0
#
#           company_txt job_state same_state  age  python_yn  R_yn spark_yn  \
# 0       IT Concepts\n        MD          0   17          0     0        0
# 1  CK-12 Foundation\n        CA          1   13          0     0        0
# 2     Credit Sesame\n        CA          1   10          1     0        1
# 3     Credit Sesame\n        CA          1   10          1     0        1
# 4     Credit Sesame\n        CA          1   10          1     0        1
#
#   aws_yn  excel_yn
# 0      0         0
# 1      1         1
# 2      1         0
# 3      1         0
# 4      1         0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'avg_salary', 'company_txt', 'job_state',
#        'same_state', 'age', 'python_yn', 'R_yn', 'spark_yn', 'aws_yn',
#        'excel_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'
		
## Job title and seniority 
		
##  Fix state Los Angeles 

##  Job description length 

##  Competitor count

## hourly wage to annual 

#remove new line from job title

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    310
# na                155
# data engineer     134
# analyst           112
# mle                26
# manager            20
# director            4
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        520
# senior    241
# Name: seniority, dtype: int64

# %%
##  Fix state Los Angeles 
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.job_state.value_counts()
# Out:
# CA    190
# NY     77
# TX     45
# MA     44
# VA     42
# IL     38
# WA     35
# MD     27
# NC     24
# PA     23
# FL     23
# OH     19
# NJ     19
# MO     18
# CO     18
# DC     14
# AZ     12
# GA     11
# WI      9
# IA      9
# AL      6
# KY      6
# TN      6
# MI      6
# NM      5
# LA      5
# NH      5
# DE      4
# UT      4
# MN      4
# OK      2
# ID      2
# IN      2
# NE      2
# ND      1
# OR      1
# CT      1
# MT      1
# KS      1
# Name: job_state, dtype: int64

# %%
##  Job description length 
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2723
# 1      4743
# 2      3556
# 3      3556
# 4      3556
#        ...
# 756    2801
# 757    2801
# 758    3799
# 759    3799
# 760    3846
# Name: desc_len, Length: 761, dtype: int64

# %%
##  Competitor count
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
## hourly wage to annual 
df['avg_salary'] = df.apply(lambda x: x.avg_salary*2 if x.hourly == 1 else x.avg_salary, axis = 1)

# %%
df[df.hourly ==1][['hourly', 'avg_salary']]
# Out:
#      hourly  avg_salary
# 744       1        42.0
# 745       1        42.0
# 746       1        38.0
# 747       1        38.0
# 748       1        38.0
# 749       1        36.0
# 750       1        36.0
# 751       1        36.0
# 752       1        36.0
# 753       1        36.0

# %%
#remove new line from job title
df['company_txt'] = df['company_txt'].apply(lambda x: x.replace('\n', ''))

# %%
df['company_txt']
# Out:
# 0                                 IT Concepts
# 1                            CK-12 Foundation
# 2                               Credit Sesame
# 3                               Credit Sesame
# 4                               Credit Sesame
#                         ...
# 756                          Beebe Healthcare
# 757                          Beebe Healthcare
# 758                            Pro-Sphere Tek
# 759                            Pro-Sphere Tek
# 760    Central California Alliance for Health
# Name: company_txt, Length: 761, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  avg_salary  \
# count  761.000000   761.000000  761.000000         761.000000  758.000000
# mean     3.669908  1821.131406    0.013141           0.009198   82.939314
# std      0.796787   539.527319    0.113952           0.095529   34.445124
# min     -1.000000    -1.000000    0.000000           0.000000    1.000000
# 25%      3.300000  1952.000000    0.000000           0.000000   56.000000
# 50%      3.700000  1992.000000    0.000000           0.000000   80.000000
# 75%      4.100000  2007.000000    0.000000           0.000000  102.000000
# max      5.000000  2020.000000    1.000000           1.000000  197.000000
#
#        same_state         age   python_yn   R_yn    spark_yn      aws_yn  \
# count  761.000000  761.000000  761.000000  761.0  761.000000  761.000000
# mean     0.559790   36.789750    0.609724    0.0    0.204993    0.248357
# std      0.496739   38.796438    0.488133    0.0    0.403962    0.432344
# min      0.000000   -1.000000    0.000000    0.0    0.000000    0.000000
# 25%      0.000000   10.000000    0.000000    0.0    0.000000    0.000000
# 50%      1.000000   24.000000    1.000000    0.0    0.000000    0.000000
# 75%      1.000000   52.000000    1.000000    0.0    0.000000    0.000000
# max      1.000000  276.000000    1.000000    0.0    1.000000    1.000000
#
#          excel_yn      desc_len    num_comp
# count  761.000000    761.000000  761.000000
# mean     0.492773   3667.137976    1.065703
# std      0.500277   1598.168761    1.360493
# min      0.000000    356.000000    0.000000
# 25%      0.000000   2496.000000    0.000000
# 50%      0.000000   3478.000000    0.000000
# 75%      1.000000   4582.000000    3.000000
# max      1.000000  10051.000000    3.000000

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['age', 'avg_salary', 'Rating'])

# %%
df.boxplot(column = 'Rating')

# %%
df[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000   -0.165764 -0.013583  0.129189
# avg_salary -0.165764    1.000000  0.036465 -0.055574
# Rating     -0.013583    0.036465  1.000000 -0.107746
# desc_len    0.129189   -0.055574 -0.107746  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age', 'avg_salary', 'Rating', 'desc_len', 'num_comp']].corr(), vmax = .3, center= 0, cmap=cmap,
           square=True, linewidths= .5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'avg_salary', 'company_txt', 'job_state',
#        'same_state', 'age', 'python_yn', 'R_yn', 'spark_yn', 'aws_yn',
#        'excel_yn', 'job_simp', 'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state','python_yn', 'R_yn', 'spark_yn', 'aws_yn',
       'excel_yn', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print('Graph for %s: total = %d' % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# Graph for Location: total = 186
# Graph for Headquarters: total = 188
# Graph for Size: total = 8
# Graph for Type of ownership: total = 11
# Graph for Industry: total = 58
# Graph for Sector: total = 25
# Graph for Revenue: total = 13
# Graph for company_txt: total = 348
# Graph for job_state: total = 39
# Graph for same_state: total = 2
# Graph for python_yn: total = 2
# Graph for R_yn: total = 1
# Graph for spark_yn: total = 2
# Graph for aws_yn: total = 2
# Graph for excel_yn: total = 2
# Graph for job_simp: total = 7
# Graph for seniority: total = 2

# %%
for i in df_cat[['Location', 'Headquarters', 'company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print('Graph for %s: total = %d' % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# Graph for Location: total = 20
# Graph for Headquarters: total = 20
# Graph for company_txt: total = 20

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          57.089286
# data engineer    96.734848
# data scientist   91.338710
# director        104.500000
# manager          67.947368
# mle             110.115385
# na               69.793548

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        na          53.258824
#                senior      69.148148
# data engineer  na          84.213333
#                senior     113.210526
# data scientist na          84.745192
#                senior     104.784314
# director       na         104.500000
# manager        na          71.875000
#                senior      47.000000
# mle            na          98.529412
#                senior     132.000000
# na             na          63.571429
#                senior      86.000000

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['job_state', 'job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        na                       2
#           manager                  3
#           data scientist           3
#           analyst                  1
# WA        na                       1
# ...                              ...
# AZ        analyst                  1
#           na                       2
#           data engineer            6
# AL        na                       2
#           analyst                  4
#
# [119 rows x 1 columns]

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
# TN         130.000000
# NJ         120.333333
# UT         111.500000
# DC         108.166667
# CA         105.000000
# WI         104.000000
# CT          99.000000
# VA          95.913043
# GA          91.000000
# CO          90.545455
# IL          88.083333
# MA          87.047619
# WA          86.560000
# NY          85.656250
# MD          85.235294
# TX          84.736842
# OH          82.272727
# PA          81.400000
# MO          78.333333
# FL          76.125000
# MN          75.000000
# MI          73.600000
# OK          69.000000
# AZ          68.333333
# NC          61.400000
# OR          56.000000
# IN          54.000000
# KY          44.000000

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employer_provided', 'python_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values ="avg_salary").sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
#  5.0    111.000000
#  4.2     97.562500
#  3.5     95.050000
# -1.0     94.727273
#  3.9     93.370370
#  4.7     91.863636
#  3.0     90.900000
#  3.3     90.194444
#  4.4     88.470588
#  3.8     85.800000
#  2.5     85.750000
#  4.0     84.302326
#  3.7     83.836066
#  3.6     77.819672
#  3.1     77.535714
#  4.1     76.441176
#  3.4     76.093023
#  4.5     75.500000
#  3.2     74.948718
#  4.8     74.000000
#  2.7     73.800000
#  4.3     72.708333
#  2.6     71.250000
#  2.2     71.000000
#  4.6     68.294118
#  2.8     68.083333
#  2.3     67.000000
#  2.9     61.300000
#  4.9     61.166667
#  2.4     56.500000
#  2.0     39.000000
# Industry
#                                          avg_salary
# Industry
# Financial Transaction Processing         146.000000
# Internet                                 116.674419
# K-12 Education                           116.600000
# Accounting                               112.000000
# Electrical & Electronic Manufacturing    110.000000
# Auctions & Galleries                     103.000000
# Financial Analytics & Research           101.600000
# Insurance Agencies & Brokerages           99.500000
# Computer Hardware & Software              99.500000
# Utilities                                 98.833333
# Cable, Internet & Telephone Providers     97.000000
# Aerospace & Defense                       96.918919
# -1                                        96.272727
# Transportation Equipment Manufacturing    96.000000
# Video Games                               94.000000
# Telecommunications Services               90.500000
# Enterprise Software & Network Solutions   87.131579
# Research & Development                    86.608696
# Insurance Carriers                        86.400000
# Mining                                    85.000000
# Biotech & Pharmaceuticals                 83.223881
# Travel Agencies                           82.375000
# IT Services                               81.870370
# Security Services                         81.000000
# Colleges & Universities                   81.000000
# Education Training Services               80.000000
# Lending                                   79.562500
# Energy                                    78.269231
# Investment Banking & Asset Management     78.095238
# Advertising & Marketing                   76.850000
# Consulting                                76.619048
# Federal Agencies                          75.500000
# Legal                                     74.000000
# Staffing & Outsourcing                    72.913043
# Wholesale                                 72.500000
# Consumer Product Rental                   71.000000
# Health, Beauty, & Fitness                 70.500000
# Consumer Products Manufacturing           69.400000
# Social Assistance                         64.666667
# Health Care Services & Hospitals          64.600000
# Brokerage Services                        64.000000
# Real Estate                               63.800000
# Venture Capital & Private Equity          63.000000
# Sporting Goods Stores                     61.000000
# Food & Beverage Manufacturing             60.636364
# Sports & Recreation                       60.000000
# Logistics & Supply Chain                  59.857143
# TV Broadcast & Cable Networks             57.000000
# Banks & Credit Unions                     55.772727
# Convenience Stores & Truck Stops          55.500000
# Industrial Manufacturing                  54.600000
# Farm Support Services                     54.000000
# Trucking                                  53.000000
# Gambling                                  52.000000
# Health Care Products Manufacturing        50.750000
# Architectural & Engineering Services      50.200000
# Health Fundraising Organizations          46.000000
# Other Retail Stores                       35.250000
# Sector
#                                    avg_salary
# Sector
# Education                          104.600000
# Aerospace & Defense                 96.918919
# -1                                  96.272727
# Information Technology              96.133005
# Telecommunications                  95.375000
# Insurance                           87.023810
# Mining & Metals                     85.000000
# Biotech & Pharmaceuticals           83.223881
# Travel & Tourism                    82.375000
# Oil, Gas, Energy & Utilities        82.125000
# Media                               81.666667
# Accounting & Legal                  80.333333
# Business Services                   77.111111
# Government                          75.500000
# Finance                             74.920000
# Consumer Services                   70.666667
# Manufacturing                       67.400000
# Health Care                         64.600000
# Real Estate                         63.800000
# Transportation & Logistics          59.000000
# Non-Profit                          57.200000
# Restaurants, Bars & Food Services   55.500000
# Arts, Entertainment & Recreation    54.666667
# Agriculture & Forestry              54.000000
# Retail                              50.833333
# Revenue
#                                   avg_salary
# Revenue
# Less than $1 million (USD)        112.000000
# $2 to $5 billion (USD)             95.705882
# $10 to $25 million (USD)           94.175000
# $50 to $100 million (USD)          92.878788
# $10+ billion (USD)                 87.236842
# Unknown / Non-Applicable           86.736041
# $1 to $5 million (USD)             85.250000
# $5 to $10 million (USD)            85.222222
# $1 to $2 billion (USD)             80.372549
# $5 to $10 billion (USD)            76.233333
# $100 to $500 million (USD)         72.905983
# $500 million to $1 billion (USD)   72.887097
# $25 to $50 million (USD)           64.977778
# num_comp
#           avg_salary
# num_comp
# 3          87.022124
# 2          86.596154
# 0          81.365854
# 1          69.034483
# hourly
#         avg_salary
# hourly
# 0        83.542781
# 1        37.800000
# employer_provided
#                    avg_salary
# employer_provided
# 1                  102.142857
# 0                   82.760320
# python_yn
#            avg_salary
# python_yn
# 1           90.809524
# 0           70.655405
# spark_yn
#           avg_salary
# spark_yn
# 1          93.044872
# 0          80.320598
# aws_yn
#         avg_salary
# aws_yn
# 1        92.278075
# 0        79.880911
# excel_yn
#           avg_salary
# excel_yn
# 0          88.187990
# 1          77.578667
# Type of ownership
#                                 avg_salary
# Type of ownership
# School / School District         93.000000
# Company - Public                 91.156069
# Government                       85.666667
# Unknown                          83.625000
# Company - Private                82.227571
# College / University             82.000000
# Subsidiary or Business Segment   77.476190
# Private Practice / Firm          75.000000
# Nonprofit Organization           62.738095
# Other Organization               55.500000
# Hospital                         38.000000
# avg_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-5c70b6f84e31> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots, index = i, values ="avg_salary").sort_values('avg_salary', ascending = False))
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      98         values = list(values)
#      99
# --> 100     grouped = data.groupby(keys, observed=observed)
#     101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     623                 in_axis=in_axis,
#     624             )
# --> 625             if not isinstance(gpr, Grouping)
#     626             else gpr
#     627         )
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     343                 if getattr(self.grouper, "ndim", 1) != 1:
#     344                     t = self.name or str(type(self.grouper))
# --> 345                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     346                 self.grouper = self.index.map(self.grouper)
#     347                 if not (
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   35.0
# $1 to $5 million (USD)             NaN   12.0
# $10 to $25 million (USD)          14.0   26.0
# $10+ billion (USD)                26.0   50.0
# $100 to $500 million (USD)        53.0   64.0
# $2 to $5 billion (USD)            24.0   27.0
# $25 to $50 million (USD)          23.0   22.0
# $5 to $10 billion (USD)           14.0   16.0
# $5 to $10 million (USD)            4.0    5.0
# $50 to $100 million (USD)         19.0   47.0
# $500 million to $1 billion (USD)  32.0   30.0
# Less than $1 million (USD)         NaN    2.0
# Unknown / Non-Applicable          71.0  126.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
